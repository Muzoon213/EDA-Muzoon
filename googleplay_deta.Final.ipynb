# %% [markdown]
# # import the liabraries

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Read dataset

# %%
googleplay_df = pd.read_csv('googleplaystore.csv')

# %%
googleplay_df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
#display the 10 head in dataset

googleplay_df.head(10)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN     4.4
# 6            Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                   Infinite Painter  ART_AND_DESIGN     4.1
# 8                               Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                      Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# ...

# %%
#display the 10 tail in dataset
googleplay_df.tail(10)
# Out:
#                                                  App             Category  \
# 10831                       payermonstationnement.fr  MAPS_AND_NAVIGATION
# 10832                                       FR Tides              WEATHER
# 10833                                    Chemin (fr)  BOOKS_AND_REFERENCE
# 10834                                  FR Calculator               FAMILY
# 10835                                       FR Forms             BUSINESS
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10831     NaN      38                9.8M       5,000+  Free     0
# ...

# %%
#display the shape in dataset
googleplay_df.shape
# Out:
# (10841, 13)

# %%
#display more information about the dataset

googleplay_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
#display the sum of the null values for each columns
googleplay_df.isna().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
#display the coulmns
googleplay_df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
#striping the columns
googleplay_df.columns = [column.strip() for column in googleplay_df.columns]

# %%
googleplay_df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
#dropoing the duplicated rows in dataset
googleapp_deta=googleplay_df.drop_duplicates(inplace = True)

# %%
googleplay_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10358 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10358 non-null  object
#  1   Category        10358 non-null  object
#  2   Rating          8893 non-null   float64
#  3   Reviews         10358 non-null  object
#  4   Size            10358 non-null  object
#  5   Installs        10358 non-null  object
#  6   Type            10357 non-null  object
#  7   Price           10358 non-null  object
#  8   Content Rating  10357 non-null  object
#  9   Genres          10358 non-null  object
#  10  Last Updated    10358 non-null  object
#  11  Current Ver     10350 non-null  object
#  12  Android Ver     10355 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
googleplay_df.describe()
# Out:
#             Rating
# count  8893.000000
# mean      4.189542
# std       0.545452
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
#display the null values for each coulmns

googleapp_deta=googleplay_df.columns.isnull()

# %%
~googleplay_df.isnull()
# Out:
#         App  Category  Rating  Reviews  Size  Installs  Type  Price  \
# 0      True      True    True     True  True      True  True   True
# 1      True      True    True     True  True      True  True   True
# 2      True      True    True     True  True      True  True   True
# 3      True      True    True     True  True      True  True   True
# 4      True      True    True     True  True      True  True   True
# ...     ...       ...     ...      ...   ...       ...   ...    ...
# 10836  True      True    True     True  True      True  True   True
# 10837  True      True    True     True  True      True  True   True
# 10838  True      True   False     True  True      True  True   True
# 10839  True      True    True     True  True      True  True   True
# 10840  True      True    True     True  True      True  True   True
#
#        Content Rating  Genres  Last Updated  Current Ver  Android Ver
# 0                True    True          True         True         True
# ...

# %%
googleapp_deta
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False])

# %%
googleplay_df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
#dropping a columns
googleapp_deta=googleplay_df.drop(["Rating"] , axis=1 , inplace=True)

# %%
googleapp_deta

# %%
googleplay_df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
#rename a colum name
googleapp_deta=googleplay_df.rename(columns={'Current Ver': 'Current_ver'}, inplace=True)

# %%
googleplay_df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
#dropping a row by index
googleplay_df.drop(googleplay_df[googleplay_df['Size'] == 'Varies with device'].index, inplace=True)

# %%
googleplay_df
# Out:
#                                                      App        Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1                                    Coloring book moana  ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint  ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
# ...                                                  ...             ...
# 10835                                           FR Forms        BUSINESS
# 10836                                   Sya9a Maroc - FR          FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings          FAMILY
# 10838                             Parkinson Exercices FR         MEDICAL
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology       LIFESTYLE
#
#       Reviews  Size     Installs  Type Price Content Rating  \
# ...

# %%
#rename a colum
googleapp_deta=googleplay_df.rename(columns={'Android Ver': 'Android_Ver'}, inplace=True)

# %%
googleplay_df
# Out:
#                                                      App        Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1                                    Coloring book moana  ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint  ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
# ...                                                  ...             ...
# 10835                                           FR Forms        BUSINESS
# 10836                                   Sya9a Maroc - FR          FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings          FAMILY
# 10838                             Parkinson Exercices FR         MEDICAL
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology       LIFESTYLE
#
#       Reviews  Size     Installs  Type Price Content Rating  \
# ...

# %%
#fillin a null value
googleapp_deta=googleplay_df.Android_Ver.fillna('Varies with device', inplace=True)

# %%
googleplay_df.Android_Ver.isna().sum()
# Out:
# 0

# %%
#rename a colum
googleapp_deta=googleplay_df.rename(columns={'Content Rating': 'Content_Rating'}, inplace=True)

# %%
googleplay_df
# Out:
#                                                      App        Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1                                    Coloring book moana  ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint  ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
# ...                                                  ...             ...
# 10835                                           FR Forms        BUSINESS
# 10836                                   Sya9a Maroc - FR          FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings          FAMILY
# 10838                             Parkinson Exercices FR         MEDICAL
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology       LIFESTYLE
#
#       Reviews  Size     Installs  Type Price Content_Rating  \
# ...

# %%
#fillin a null value
googleapp_deta=googleplay_df.Content_Rating.fillna('Everyone', inplace=True)

# %%
googleplay_df
# Out:
#                                                      App        Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1                                    Coloring book moana  ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint  ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
# ...                                                  ...             ...
# 10835                                           FR Forms        BUSINESS
# 10836                                   Sya9a Maroc - FR          FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings          FAMILY
# 10838                             Parkinson Exercices FR         MEDICAL
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology       LIFESTYLE
#
#       Reviews  Size     Installs  Type Price Content_Rating  \
# ...

# %%
#rename a colum
googleapp_new=googleplay_df.rename(columns={'Last Updated' : 'Last_Updated'}, inplace=True)

# %%
googleplay_df
# Out:
#                                                      App        Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1                                    Coloring book moana  ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint  ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
# ...                                                  ...             ...
# 10835                                           FR Forms        BUSINESS
# 10836                                   Sya9a Maroc - FR          FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings          FAMILY
# 10838                             Parkinson Exercices FR         MEDICAL
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology       LIFESTYLE
#
#       Reviews  Size     Installs  Type Price Content_Rating  \
# ...

# %%
googleplay_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8832 entries, 0 to 10840
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             8832 non-null   object
#  1   Category        8832 non-null   object
#  2   Reviews         8832 non-null   object
#  3   Size            8832 non-null   object
#  4   Installs        8832 non-null   object
#  5   Type            8832 non-null   object
#  6   Price           8832 non-null   object
#  7   Content_Rating  8832 non-null   object
#  8   Genres          8832 non-null   object
#  9   Last_Updated    8832 non-null   object
#  10  Current_ver     8824 non-null   object
#  11  Android_Ver     8832 non-null   object
# dtypes: object(12)
# memory usage: 897.0+ KB

# %%
#check null
googleplay_df.isna().sum()
# Out:
# App               0
# Category          0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content_Rating    0
# Genres            0
# Last_Updated      0
# Current_ver       8
# Android_Ver       0
# dtype: int64

# %%
#fillin a null value
googleapp_deta=googleplay_df.Current_ver.fillna('Varies with device', inplace=True)

# %%
googleplay_df.isna().sum()
# Out:
# App               0
# Category          0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content_Rating    0
# Genres            0
# Last_Updated      0
# Current_ver       0
# Android_Ver       0
# dtype: int64

# %%
#replacing str with nothing '' to change the data type

googleplay_df['Size']=googleplay_df['Size'].str.replace('M','')
googleplay_df['Size']=googleplay_df['Size'].str.replace('k','')

# %%
googleplay_df
# Out:
#                                                      App        Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1                                    Coloring book moana  ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint  ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
# ...                                                  ...             ...
# 10835                                           FR Forms        BUSINESS
# 10836                                   Sya9a Maroc - FR          FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings          FAMILY
# 10838                             Parkinson Exercices FR         MEDICAL
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology       LIFESTYLE
#
#       Reviews Size     Installs  Type Price Content_Rating  \
# ...

# %%
googleplay_df.Size.dtype
# Out:
# dtype('O')

# %%
googleplay_df.drop(googleplay_df[googleplay_df['Size'] == '1,000+'].index, inplace=True)

# %%
googleplay_df.Size=googleplay_df.Size.astype('float')

# %%
googleplay_df.Size.dtype
# Out:
# dtype('float64')

# %%
#googleplay_df = pd.read_csv('googleplaystore.csv')
#googleapp_deta['Installs']=
googleplay_df['Installs']=googleplay_df['Installs'].str.replace('+','').str.replace(',' ,'')
googleplay_df['Installs']
#googleapp_deta['Installs']=googleplay_df['Installs'].str.replace(',','')
# Out:
# <ipython-input-52-1b7a10ca3cb7>:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   googleplay_df['Installs']=googleplay_df['Installs'].str.replace('+','').str.replace(',' ,'')
# 0           10000
# 1          500000
# 2         5000000
# 3        50000000
# 4          100000
#            ...
# 10835          10
# 10836        5000
# 10837         100
# 10838        1000
# 10840    10000000
# Name: Installs, Length: 8831, dtype: object

# %%
googleplay_df
# Out:
#                                                      App        Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1                                    Coloring book moana  ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint  ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
# ...                                                  ...             ...
# 10835                                           FR Forms        BUSINESS
# 10836                                   Sya9a Maroc - FR          FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings          FAMILY
# 10838                             Parkinson Exercices FR         MEDICAL
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology       LIFESTYLE
#
#       Reviews  Size  Installs  Type Price Content_Rating  \
# ...

# %%
googleapp_deta=googleplay_df.drop(['Price'], axis=1 , inplace=True)

# %%
googleplay_df
# Out:
#                                                      App        Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1                                    Coloring book moana  ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint  ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
# ...                                                  ...             ...
# 10835                                           FR Forms        BUSINESS
# 10836                                   Sya9a Maroc - FR          FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings          FAMILY
# 10838                             Parkinson Exercices FR         MEDICAL
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology       LIFESTYLE
#
#       Reviews  Size  Installs  Type Content_Rating                     Genres  \
# ...

# %%
googleplay_df.Reviews=googleplay_df.Reviews.astype('float')

# %%
googleplay_df.Reviews.dtype
# Out:
# dtype('float64')

# %% [markdown]
# # How many apps in each category?

# %%
# %matplotlib inline 
#plt.figure(figsize=(60,30))
googleplay_df.groupby('Category').sum().plot.bar(figsize=(60,30))

plt.title("Number of apps by Category")
# Out:
# Text(0.5, 1.0, 'Number of apps by Category')

# %%
googleplay_df.Type.unique()
# Out:
# array(['Free', 'Paid'], dtype=object)

# %%
googleplay_df.Type.value_counts()
# Out:
# Free    8140
# Paid     691
# Name: Type, dtype: int64

# %% [markdown]
# # Which Apps type is the highest?

# %%
x= googleplay_df.Type.value_counts()
label= ["Free","Paid"]
plt.pie(x,labels= label , autopct= "%1.1f%%")
plt.show()

# %% [markdown]
# # The highest installed app categories is it free or paid?

# %%
plt.figure(figsize=(30,10))
sns.set(font_scale=2)
sns.countplot(x = "Category", hue='Type', data = googleplay_df)
plt.xticks(
    rotation=45,
    horizontalalignment='right');

# %%
googleplay_df.groupby(data).sum().plot.bar()
plt.title("Higest Content Raiting")
# Out:
# Text(0.5, 1.0, 'Higest Content Raiting')
