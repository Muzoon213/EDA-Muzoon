# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
googleplay_df = pd.read_csv('googleplaystore.csv')

# %%
googleplay_df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
googleplay_df.head(10)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN     4.4
# 6            Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                   Infinite Painter  ART_AND_DESIGN     4.1
# 8                               Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                      Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# ...

# %%
googleplay_df.tail(10)
# Out:
#                                                  App             Category  \
# 10831                       payermonstationnement.fr  MAPS_AND_NAVIGATION
# 10832                                       FR Tides              WEATHER
# 10833                                    Chemin (fr)  BOOKS_AND_REFERENCE
# 10834                                  FR Calculator               FAMILY
# 10835                                       FR Forms             BUSINESS
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10831     NaN      38                9.8M       5,000+  Free     0
# ...

# %%
googleplay_df.shape
# Out:
# (10841, 13)

# %%
googleplay_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
googleplay_df.isna().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
googleplay_df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
googleplay_df.columns = [column.strip() for column in googleplay_df.columns]

# %%
googleplay_df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
googleplay_df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
googleapp_new=googleplay_df.drop_duplicates(inplace = True)

# %%
googleplay_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10358 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10358 non-null  object
#  1   Category        10358 non-null  object
#  2   Rating          8893 non-null   float64
#  3   Reviews         10358 non-null  object
#  4   Size            10358 non-null  object
#  5   Installs        10358 non-null  object
#  6   Type            10358 non-null  object
#  7   Price           10358 non-null  object
#  8   Content_Rating  10357 non-null  object
#  9   Genres          10358 non-null  object
#  10  Last Updated    10358 non-null  object
#  11  Current_ver     10350 non-null  object
#  12  Android_Ver     10358 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
googleplay_df.values
# Out:
# array([['Photo Editor & Candy Camera & Grid & ScrapBook',
#         'ART_AND_DESIGN', 4.1, ..., '7-Jan-18', '1.0.0', '4.0.3 and up'],
#        ['Coloring book moana', 'ART_AND_DESIGN', 3.9, ..., '15-Jan-18',
#         '2.0.0', '4.0.3 and up'],
#        ['U Launcher Lite – FREE Live Cool Themes, Hide Apps',
#         'ART_AND_DESIGN', 4.7, ..., '1-Aug-18', '1.2.4', '4.0.3 and up'],
#        ...,
#        ['Parkinson Exercices FR', 'MEDICAL', nan, ..., '20-Jan-17', '1',
#         '2.2 and up'],
#        ['The SCP Foundation DB fr nn5n', 'BOOKS_AND_REFERENCE', 4.5, ...,
#         '19-Jan-15', 'Varies with device', 'Varies with device'],
#        ['iHoroscope - 2018 Daily Horoscope & Astrology', 'LIFESTYLE',
#         4.5, ..., '25-Jul-18', 'Varies with device',
#         'Varies with device']], dtype=object)

# %%
googleplay_df.describe()
# Out:
#             Rating
# count  8893.000000
# mean      4.189542
# std       0.545452
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
googleapp_new=googleplay_df.columns.isnull()

# %%
~googleplay_df.isnull()
# Out:
#         App  Category  Rating  Reviews  Size  Installs  Type  Price  \
# 0      True      True    True     True  True      True  True   True
# 1      True      True    True     True  True      True  True   True
# 2      True      True    True     True  True      True  True   True
# 3      True      True    True     True  True      True  True   True
# 4      True      True    True     True  True      True  True   True
# ...     ...       ...     ...      ...   ...       ...   ...    ...
# 10836  True      True    True     True  True      True  True   True
# 10837  True      True    True     True  True      True  True   True
# 10838  True      True   False     True  True      True  True   True
# 10839  True      True    True     True  True      True  True   True
# 10840  True      True    True     True  True      True  True   True
#
#        Content_Rating  Genres  Last Updated  Current_ver  Android_Ver
# 0                True    True          True         True         True
# ...

# %%
~googleplay_df.Rating.isnull()
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 10836     True
# 10837     True
# 10838    False
# 10839     True
# 10840     True
# Name: Rating, Length: 10358, dtype: bool

# %%
googleplay_df[googleplay_df.Rating.isna()]
# Out:
#                                        App             Category  Rating  \
# 23                  Mcqueen Coloring pages       ART_AND_DESIGN     NaN
# 113              Wrinkles and rejuvenation               BEAUTY     NaN
# 123                 Manicure - nail design               BEAUTY     NaN
# 126           Skin Care and Natural Beauty               BEAUTY     NaN
# 129    Secrets of beauty, youth and health               BEAUTY     NaN
# ...                                    ...                  ...     ...
# 10824                            Cardio-FR              MEDICAL     NaN
# 10825                   Naruto & Boruto FR               SOCIAL     NaN
# 10831             payermonstationnement.fr  MAPS_AND_NAVIGATION     NaN
# 10835                             FR Forms             BUSINESS     NaN
# 10838               Parkinson Exercices FR              MEDICAL     NaN
#
#       Reviews  Size  Installs  Type Price Content Rating  \
# ...

# %%
googleplay_df.shape
# Out:
# (10358, 13)

# %%
googleapp_new=googleplay_df.drop(["Rating"] , axis=1 , inplace=True)

# %%
googleapp_new

# %%
googleapp_new=googleplay_df.rename(columns={'Current Ver': 'Current_ver'}, inplace=True)

# %%
googleapp_new

# %%
googleplay_df.Current_ver.fillna('Varies with device' , inplace=True)

# %%
googleapp_new=googleplay_df.rename(columns={'Android Ver': 'Android_Ver'}, inplace=True)

# %%
googleapp_new

# %%
googleplay_df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
googleapp_new=googleplay_df.Android_Ver.fillna('Varies with device', inplace=True)

# %%
googleplay_df.Android_Ver.isna().sum()
# Out:
# 0

# %%
googleapp_new=googleplay_df.rename(columns={'Content Rating': 'Content_Rating'}, inplace=True)

# %%
googleapp_new

# %%
googleplay_df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
googleplay_df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
googleplay_df.isna().sum()
# Out:
# App               0
# Category          0
# Reviews           0
# Size              0
# Installs          0
# Price             0
# Content_Rating    0
# Genres            0
# Last_Updated      0
# Current_ver       0
# Android_Ver       0
# dtype: int64

# %%
googleapp_new=googleplay_df.Content_Rating.fillna('Everyone', inplace=True)

# %%
googleplay_df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
googleplay_df.isna().sum()
# Out:
# App               0
# Category          0
# Reviews           0
# Size              0
# Installs          0
# Price             0
# Content_Rating    0
# Genres            0
# Last_Updated      0
# Current_ver       0
# Android_Ver       0
# dtype: int64

# %%
googleplay_df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
googleapp_new=googleplay_df.drop(["Price"] , axis=1 , inplace=True)

# %%
googleplay_df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
googleapp_new=googleplay_df.rename(columns={'Type': 'Price' , 'Last Updated' : 'Last_Updated'}, inplace=True)

# %%
googleplay_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10358 entries, 0 to 10840
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10358 non-null  object
#  1   Category        10358 non-null  object
#  2   Reviews         10358 non-null  object
#  3   Size            10358 non-null  object
#  4   Installs        10358 non-null  object
#  5   Price           10358 non-null  object
#  6   Content_Rating  10358 non-null  object
#  7   Genres          10358 non-null  object
#  8   Last_Updated    10358 non-null  object
#  9   Current_ver     10358 non-null  object
#  10  Android_Ver     10358 non-null  object
# dtypes: object(11)
# memory usage: 971.1+ KB

# %%
googleapp_new=googleplay_df['Size']=googleplay_df['Size'].str.replace('M', '')

# %%
googleplay_df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
googleapp_new=googleplay_df['Size']=googleplay_df['Size'].str.replace('K', '')

# %%
googleplay_df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
googleplay_df['Size']=googleplay_df['Size'].replace('M','000')
googleplay_df['Size']=googleplay_df['Size'].replace('k','')

# %%
googleplay_df['Size'].value_counts()
# Out:
# 0.0      1526
# 11.0      189
# 13.0      186
# 12.0      186
# 14.0      183
#          ...
# 963.0       1
# 688.0       1
# 892.0       1
# 293.0       1
# 259.0       1
# Name: Size, Length: 421, dtype: int64

# %%
googleplay_df['Size'].replace('Varies with device', np.nan, inplace = True )

# %%
googleplay_df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
googleplay_df['Size'].unique()
# Out:
# array([1.90e+01, 1.40e+01, 8.70e+00, 2.50e+01, 2.80e+00, 5.60e+00,
#        2.90e+01, 3.30e+01, 3.10e+00, 2.80e+01, 1.20e+01, 2.00e+01,
#        2.10e+01, 3.70e+01, 2.70e+00, 5.50e+00, 1.70e+01, 3.90e+01,
#        3.10e+01, 4.20e+00, 7.00e+00, 2.30e+01, 6.00e+00, 6.10e+00,
#        4.60e+00, 9.20e+00, 5.20e+00, 1.10e+01, 2.40e+01, 0.00e+00,
#        9.40e+00, 1.50e+01, 1.00e+01, 1.20e+00, 2.60e+01, 8.00e+00,
#        7.90e+00, 5.60e+01, 5.70e+01, 3.50e+01, 5.40e+01, 2.01e+02,
#        3.60e+00, 5.70e+00, 8.60e+00, 2.40e+00, 2.70e+01, 2.50e+00,
#        1.60e+01, 3.40e+00, 8.90e+00, 3.90e+00, 2.90e+00, 3.80e+01,
#        3.20e+01, 5.40e+00, 1.80e+01, 1.10e+00, 2.20e+00, 4.50e+00,
#        9.80e+00, 5.20e+01, 9.00e+00, 6.70e+00, 3.00e+01, 2.60e+00,
#        7.10e+00, 3.70e+00, 2.20e+01, 7.40e+00, 6.40e+00, 3.20e+00,
#        8.20e+00, 9.90e+00, 4.90e+00, 9.50e+00, 5.00e+00, 5.90e+00,
#        1.30e+01, 7.30e+01, 6.80e+00, 3.50e+00, 4.00e+00, 2.30e+00,
# ...

# %%
googleplay_df[googleplay_df['Size'] == '1,000+']
# Out:
# Empty DataFrame
# Columns: [App, Category, Reviews, Size, Installs, Price, Content_Rating, Genres, Last_Updated, Current_ver, Android_Ver]
# Index: []

# %%
googleplay_df['Size'].unique()
# Out:
# array([1.90e+01, 1.40e+01, 8.70e+00, 2.50e+01, 2.80e+00, 5.60e+00,
#        2.90e+01, 3.30e+01, 3.10e+00, 2.80e+01, 1.20e+01, 2.00e+01,
#        2.10e+01, 3.70e+01, 2.70e+00, 5.50e+00, 1.70e+01, 3.90e+01,
#        3.10e+01, 4.20e+00, 7.00e+00, 2.30e+01, 6.00e+00, 6.10e+00,
#        4.60e+00, 9.20e+00, 5.20e+00, 1.10e+01, 2.40e+01, 0.00e+00,
#        9.40e+00, 1.50e+01, 1.00e+01, 1.20e+00, 2.60e+01, 8.00e+00,
#        7.90e+00, 5.60e+01, 5.70e+01, 3.50e+01, 5.40e+01, 2.01e+02,
#        3.60e+00, 5.70e+00, 8.60e+00, 2.40e+00, 2.70e+01, 2.50e+00,
#        1.60e+01, 3.40e+00, 8.90e+00, 3.90e+00, 2.90e+00, 3.80e+01,
#        3.20e+01, 5.40e+00, 1.80e+01, 1.10e+00, 2.20e+00, 4.50e+00,
#        9.80e+00, 5.20e+01, 9.00e+00, 6.70e+00, 3.00e+01, 2.60e+00,
#        7.10e+00, 3.70e+00, 2.20e+01, 7.40e+00, 6.40e+00, 3.20e+00,
#        8.20e+00, 9.90e+00, 4.90e+00, 9.50e+00, 5.00e+00, 5.90e+00,
#        1.30e+01, 7.30e+01, 6.80e+00, 3.50e+00, 4.00e+00, 2.30e+00,
# ...

# %%
googleplay_df['Size'].value_counts()
# Out:
# 0.0      1526
# 11.0      189
# 13.0      186
# 12.0      186
# 14.0      183
#          ...
# 963.0       1
# 688.0       1
# 892.0       1
# 293.0       1
# 259.0       1
# Name: Size, Length: 421, dtype: int64

# %%
googleplay_df.Reviews.dtype
# Out:
# dtype('int32')

# %%
googleplay_df.Reviews=googleplay_df.Reviews.astype('int')

# %%
googleplay_df.Reviews.dtype
# Out:
# dtype('int32')

# %%
googleplay_df.Size=googleplay_df.Size.astype('float')

# %%
googleplay_df.Size.dtype
# Out:
# dtype('float64')

# %%
googleplay_df['Installs'].dtype
# Out:
# dtype('int32')

# %%
googleplay_df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
googleapp_new=googleplay_df['Installs'].replace('+','')

# %%
googleplay_df.Installs.value_counts()
# Out:
# 1000000       1488
# 10000000      1132
# 100000        1129
# 10000         1033
# 1000           890
# 100            710
# 5000000        683
# 500000         517
# 50000          474
# 5000           469
# 10             385
# 100000000      369
# 500            328
# 50000000       272
# 50             204
# 5               82
# 1               67
# 500000000       61
# 1000000000      49
# 0               15
# Name: Installs, dtype: int64

# %%
googleapp_new=googleplay_df.Installs=googleplay_df.Installs.astype('int')

# %%
googleplay_df.Installs.dtype
# Out:
# dtype('int32')

# %%
googleplay_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10357 entries, 0 to 10840
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10357 non-null  object
#  1   Category        10357 non-null  object
#  2   Reviews         10357 non-null  int32
#  3   Size            10357 non-null  float64
#  4   Installs        10357 non-null  int32
#  5   Price           10357 non-null  object
#  6   Content_Rating  10357 non-null  object
#  7   Genres          10357 non-null  object
#  8   Last_Updated    10357 non-null  object
#  9   Current_ver     10357 non-null  object
#  10  Android_Ver     10357 non-null  object
# dtypes: float64(1), int32(2), object(8)
# memory usage: 1.1+ MB

# %%
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
googleplay_df["Category"].value_counts().head(15).plot(kind = "bar")
plt.title("Category", fontsize=16)
# Out:
# Text(0.5, 1.0, 'Category')

# %%
googleplay_df["App"].value_counts().head(10).plot(kind = "pie" , autopct="%.1f%%")
# Out:
# <AxesSubplot:ylabel='App'>

# %%
googleplay_df["Installs"].value_counts().head(15).plot(kind = "bar")
plt.title("Installs")
# Out:
# Text(0.5, 1.0, 'Installs')

# %%
googleapp_new=googleplay_df

# %%
googleapp_new.describe()
# Out:
#             Reviews          Size      Installs
# count  1.035700e+04  10357.000000  1.035700e+04
# mean   4.059046e+05     31.786193  1.415776e+07
# std    2.696778e+06     93.515174  8.023955e+07
# min    0.000000e+00      0.000000  0.000000e+00
# 25%    3.200000e+01      3.200000  1.000000e+03
# 50%    1.680000e+03     10.000000  1.000000e+05
# 75%    4.641600e+04     29.000000  1.000000e+06
# max    7.815831e+07   1020.000000  1.000000e+09

# %%
len(googleapp_new)
# Out:
# 10357

# %%
googleplay_df.to_csv('googleapp_new.csv')
